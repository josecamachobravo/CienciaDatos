# %% [markdown]
# <a href="https://colab.research.google.com/github/josecamachobravo/CienciaDatos/blob/main/NewBusquedanformacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ruta = r'http://raw.githubusercontent.com/josecamachobravo/CienciaDatos/main/CienciaDatos/CNPV2018_5PER_A2_05.csv'
df = pd.read_csv(ruta)
print(df.head())
print(df.tail())
print(df.describe())
# Out:
#    TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  P_NROHOG  \
# 0         5       5       1         1           3626           4         1
# 1         5       5       1         1           3626           4         1
# 2         5       5       1         1           3626           4         1
# 3         5       5       1         1           3626           4         1
# 4         5       5       1         1           3626           4         1
#
#    P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  PA3_HSVM  PA_HFC  \
# 0          1       1        5  ...       NaN       NaN       NaN     NaN
# 1          2       2       11  ...       2.0       1.0       1.0     2.0
# 2          3       2        7  ...       1.0       0.0       1.0     2.0
# 3          4       2        1  ...       NaN       NaN       NaN     NaN
# 4          5       1       11  ...       NaN       NaN       NaN     NaN
#
#    PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  PA1_MES_UHNV  PA2_ANO_UHNV
# 0       NaN       NaN       NaN      NaN           NaN           NaN
# 1       NaN       NaN       NaN      1.0           3.0        1994.0
# 2       NaN       NaN       NaN      1.0          10.0        2013.0
# 3       NaN       NaN       NaN      NaN           NaN           NaN
# 4       NaN       NaN       NaN      NaN           NaN           NaN
#
# [5 rows x 48 columns]
#        TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  \
# 96792         5       5       1         1         901600           1
# 96793         5       5       1         1         901600           1
# 96794         5       5       1         1         901600           1
# 96795         5       5       1         1         901601           4
# 96796         5       5       1         1         901601           4
#
#        P_NROHOG  P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  \
# 96792         1          3       2        6  ...      99.0      99.0
# 96793         1          4       1        6  ...       NaN       NaN
# 96794         1          5       1       12  ...       NaN       NaN
# 96795         1          1       2        8  ...       1.0       0.0
# 96796         1          2       2        4  ...       NaN       NaN
#
#        PA3_HSVM  PA_HFC  PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  PA1_MES_UHNV  \
# 96792      99.0     2.0       NaN       NaN       NaN      1.0           7.0
# 96793       NaN     NaN       NaN       NaN       NaN      NaN           NaN
# 96794       NaN     NaN       NaN       NaN       NaN      NaN           NaN
# 96795       1.0     2.0       NaN       NaN       NaN      1.0           5.0
# 96796       NaN     NaN       NaN       NaN       NaN      NaN           NaN
#
#        PA2_ANO_UHNV
# 96792        2014.0
# 96793           NaN
# 96794           NaN
# 96795        2001.0
# 96796           NaN
#
# [5 rows x 48 columns]
#        TIPO_REG   U_DPTO   U_MPIO  UA_CLASE  COD_ENCUESTAS    U_VIVIENDA  \
# count   96797.0  96797.0  96797.0   96797.0   96797.000000  96797.000000
# mean        5.0      5.0      1.0       1.0  467555.979576     20.940432
# std         0.0      0.0      0.0       0.0  247592.254885     65.376769
# min         5.0      5.0      1.0       1.0    3626.000000      1.000000
# 25%         5.0      5.0      1.0       1.0  256645.000000      2.000000
# 50%         5.0      5.0      1.0       1.0  465583.000000      4.000000
# 75%         5.0      5.0      1.0       1.0  650299.000000     10.000000
# max         5.0      5.0      1.0       1.0  901601.000000    688.000000
#
#            P_NROHOG     P_NRO_PER        P_SEXO       P_EDADR  ...  \
# count  96797.000000  96797.000000  96797.000000  96797.000000  ...
# mean       1.031334      2.578251      1.530895      7.648997  ...
# std        0.305466      1.677919      0.499047      4.243374  ...
# min        1.000000      1.000000      1.000000      1.000000  ...
# 25%        1.000000      1.000000      1.000000      4.000000  ...
# 50%        1.000000      2.000000      2.000000      7.000000  ...
# 75%        1.000000      3.000000      2.000000     11.000000  ...
# max       18.000000     28.000000      2.000000     21.000000  ...
#
#            PA1_THSV      PA2_HSVH      PA3_HSVM        PA_HFC      PA1_THFC  \
# count  28389.000000  28389.000000  28389.000000  28824.000000  11295.000000
# mean       3.772553      2.508366      2.544507      1.611053      0.364320
# std       11.186530     11.146888     11.209523      0.510872      2.241167
# min        0.000000      0.000000      0.000000      1.000000      0.000000
# 25%        1.000000      0.000000      0.000000      1.000000      0.000000
# 50%        2.000000      1.000000      1.000000      2.000000      0.000000
# 75%        3.000000      2.000000      2.000000      2.000000      0.000000
# max       99.000000     99.000000     99.000000      9.000000     99.000000
#
#            PA2_HFCH      PA3_HFCM       PA_UHNV  PA1_MES_UHNV  PA2_ANO_UHNV
# count  11295.000000  11295.000000  28824.000000  21864.000000  21864.000000
# mean       0.194245      0.222399      2.931724      6.548024   2022.360821
# std        2.139045      2.336742      3.423834      3.779941    432.420777
# min        0.000000      0.000000      1.000000      1.000000   1938.000000
# 25%        0.000000      0.000000      1.000000      4.000000   1990.000000
# 50%        0.000000      0.000000      1.000000      7.000000   2001.000000
# 75%        0.000000      0.000000      1.000000     10.000000   2010.000000
# max       99.000000     99.000000      9.000000     99.000000   9999.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# Diplomado Ciencia de Datos
#
#         Jose Mauricio Camacho Bravo.
#         Sandra Milena Echavarría López.
#
#         Facultad de Tecnología, Universidad IUD
#
#         Actividad de aprendizaje : S33 - Búsqueda de Información
#
#
#         Profesor: Julián Andrés Castillo Grisales
#
#         Junio 28 del 2023
#
#         Universidad IUD
#
#         Medellín
#
# Introducción
#
# Hoy en día la búsqueda de la información es un ámbito que está de qué hablar ya que con procesos muy bien establecidos podemos integrar procesos de aplicaciones, base de datos, etc, que nos brinda la oportunidad de tener datos a la mano y poder personalizarlos de acuerdo a la necesidad, con este trabajo se va demostrar que si se puede tener una búsqueda de datos con buenos lineamientos y tener resultados satisfactorios. Con este proceso vamos a utilizar una herramienta para el desarrollo de la actividad que nos permite analizarlos de acuerdo a lo solicitado y tener resultados satisfactorios.
#
# Esta información corresponde al censo que se realizó en el año 2018 de hombres y mujeres por cada uno de los barrios en su totalidad, incluyendo las 16 comunas y los 5 corregimientos que tiene la ciudad de Medellín
#
# Aprendizaje:
#
# Describa el procedimiento realizado para la obtención de los datos.
#
# Para realizar esta activado se hizo una consulta en el navegador de google.com.co con la palabra poblacion Medellin, alli nos mostro la informacion correspondiente donde se evidencia el link, desde esta pagina nos muestra el icono de descargar la informacion en un archivo .CSV. http://medata.gov.co/dataset/proyecciones-de-poblaci%C3%B3n-medell%C3%ADn-2018
#
# Planteamiento del problema
#
# Con esta información se puede mostrar el total de personas que viven en un barrio tanto mujeres como hombres, y se puede hacer un análisis del crecimiento a los siguientes años tanto mujeres como hombres, con estos datos podemos hacer una estadísticas que personas viven con escasos recursos, estudio, trabajo, oportunidades de tener una vivienda propia, salud alimentación para los niños y niñas.
#
# Descripción del dataset
#
# Es el conjunto de datos que se establece en una tabla donde se especifica a cada columna un nombre que relaciones los datos según su estimación a almacenar, según estos los podemos establecer según la necesidad de la persona que adquiere la información y poder establecer estadísticas o seguimiento.
#
#         Descripción de cada columna del dataset
#
# Para realizar esta actividad se escogió una tabla que contiene las siguientes columnas:
#
# Código Dane_Municipio: Nos permite almacenar el código del Municipio según datos del DANE para cada uno de ellos. Tipo_división_geográfica: Corresponde a la zona geográfica del Municipio en este caso Medellín se distribuye por las comunas (16). Código: Es el nombre del barrio que lleva el Municipio y su respectiva comuna. Grupo_Edad: Se establece las edades según el rango para identificar quienes viven en cada una de las viviendas. Total_2018: Es el total de personas que viven en Municipio-Comuna-Barrio, es decir el total de personas que viven en el barrio. Hombres_2018: Total de hombres que viven en el Barrio. Mujeres_2018: Total de mujeres que viven en el Barrio.
#
# Lectura del documento desde GitHub https://github.com/josecamachobravo/CienciaDatos/blob/main/Busquedanformacion.ipynb
#
# Mostrar las primeras y últimas cinco filas
#
# Realizar un análisis descriptivo de los datos.
#
# De acuerdo a los datos obtenidos podemos decir que si comparamos las edades de las personas, para el año 2018, podemos concluir que para ese año las personas con edades comprendidas entre los 0 y 19 años de edad en su mayoría eran hombres, pero con un margen de diferencia muy inferior, si lo comparamos con las edades comprendidas entre los 60 años de edad y más los papeles se invierten al presentarse una mayor cantidad de mujeres que de hombres, pero en una diferencia númerica mucho mayor.
#
# Cargar el documento con extensión ipynb
#
# Busquedanformacion.ipynb
#
# https://colab.research.google.com/drive/1gY-cm6fAgKHMxSfoVpD9_VflnS9sYkS3#scrollTo=7RcCp1g164ho
#
# Desarrollo de Ruta Metodológica
#
# Después de analizar la información extraída y transformada, responde a las siguientes preguntas:
#
# ¿Qué uso podríamos darle al dataset?
#
# El uso que se le puede dar al dataset es muy importante ya con esta información podemos sacar estadísticas de personas que viven en un barrio, comuna, o que se desplazan de un barrio a otro, con esta información las autoridades gubernamentales pueden tomar acciones como mejorar la vida, calles, educación, transporte, seguridad escuelas, colegios, etc.
#
# ¿Existe alguna relación entre las columnas del documento?
#
# Si existe relación de columnas, entre ellas está el Hombre-2018 y Mujeres_2018, ya que se puede desglosar a mayor cantidad de hombre menor cantidad de mujeres o viceversa, esto quiere decir que se puede establecer que tipo de cabeza de familia se puede notar en una vivienda, es de mencionar que las estadísticas tienden a que las mujeres son la mayoría que establecen como madre y cabeza de hogar, con estos datos el Alcalde, Gobernador o Gobierno puede evidencia que necesidades se pueden dar a estas personas según el barrio o comuna.
#
# ¿Qué podríamos predecir o clasificar usando estos datos?
#
# Para clasificar estos datos el DANE-ALCALDE lo que quiere es evidencia y tener control de la cantidad de personas que somos de nacionalidad Colombiana, según estadísticas, cada 10 años, con esta información se evidencia el crecimiento que se tiene cada año tanto hombres como mujeres, con esta información se puede prevenir, la pobreza, ayudar a los más necesitados, se puede establecer niveles de estudio en cada una de las viviendas, servicios, transporte, educación salud alimentación, etc. según su calidad de vida en
#
# ¿Qué observaciones tienes de la página de donde descargaste la información? http://medata.gov.co/
#
# En cuanto a esta página de la Alcaldía de Medellín, los comentarios son positivos en cuanto a los datos que pueden ser accedidos, dado que en tiempo real y desde donde quiera que te encuentres puedes hacer una investigación amplia de acuerdo a tus necesidades e intereses, puesto que el filtro de esta; está determinado en diferentes campos, y actividades. En esta página puedes segmentar desde grupos de sisben, hasta niveles de edad, estratos socioeconómicos y todo lo que se te pueda ocurrir, ya sea llevado a nivel general de la Ciudad ó por comunas, y todo esto con sus respectivos gráficos que hacen más comprensible la información. El tipo de licencia de esta página es totalmente pública, y abierta para hacer uso de los datos que en ella están consignados, de acuerdo a la “la Ley 1712 de 2014, se podrá hacer uso, aprovechamiento y/o transformación de forma libre y sin restricciones, para hacer aplicaciones por parte de terceros y contenidos de su propia creación” https://microdatos.dane.gov.co/index.php/catalog/643/get-microdata
# condiciones-de-uso). Quien haga uso de estos datos a manera de aprovechamiento, deberá hacerlo citando textualmente la fuente del portal, y sus datos no podrán ser modificados. Dentro de las características de la página está su advertencia en caso de no cumplimiento de las políticas de privacidad , donde claramente se advierte de sanciones que podrían ser desde disciplinarias hasta legales. Es una página amigable con la forma en que muestra la información y como la segmenta. En ella también se pueden encontrar links de otras páginas de las cuales medata no tiene control, por lo cual se hace la salvedad frente al tema. Del mismo modo se aclara que pueden ser negados los servicios a ciertos usuarios a su criterio, ó modificar el contenido de ella sin tener que dar previo aviso de esto.
#
# Codifica toda la solución en un Notebook de Google Colab explicando cada paso usando las celdas de texto y código que provee esta herramienta.
#
# El desarrollo se hizo de acuerdo a los solicitado en Notebook de Google, como lo muestra la imagen
#
# Conclusiones
#
# Mediante este tipo de procesos tal y como se evidencio durante el desarrollo de la actividad, podemos llegar a filtrar los datos de las comunas con minucia, pudiendo identificar la comuna, sexo y nivel socioeconomico. Al tener la oportunidad de hacer este tipo de filtros, en determinado caso se podrían determinar con exactitud los recursos que se deben asignar a un proyecto, y en qué comuna se necesitarian con un nivel de urgencia más alto. Tener la tecnología de nuestro lado, siempre será estar un paso a la vanguardia, tanto a nivel de gastos como de funcionamiento y desarrollo de nuestro proyectos.
#
# Siempre el que tiene el conocimiento ó la información, tiene el poder, y más aún si se le da un uso adecuado teniéndolo en manos expertas. Para cada problema siempre se debe tener una solución prevista antes de que sucedan los hechos, y con este tipo de metodologías, y un monitoreo constante todo se vuelve predecible y fácil de controlar, al establecer planes de acción en caso de una emergencia.
#
# References (n.d.). MEData. Retrieved June 29, 2023, from https://microdatos.dane.gov.co/index.php/catalog/643/get-microdata
#
# References / /. (n.d.). / / - Wiktionary. Retrieved June 29, 2023, from https://microdatos.dane.gov.co/index.php/catalog/643/get-microdata

# %%
df.head()
# Out:
#    TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  P_NROHOG  \
# 0         5       5       1         1           3626           4         1
# 1         5       5       1         1           3626           4         1
# 2         5       5       1         1           3626           4         1
# 3         5       5       1         1           3626           4         1
# 4         5       5       1         1           3626           4         1
#
#    P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  PA3_HSVM  PA_HFC  \
# 0          1       1        5  ...       NaN       NaN       NaN     NaN
# 1          2       2       11  ...       2.0       1.0       1.0     2.0
# 2          3       2        7  ...       1.0       0.0       1.0     2.0
# 3          4       2        1  ...       NaN       NaN       NaN     NaN
# 4          5       1       11  ...       NaN       NaN       NaN     NaN
#
#    PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  PA1_MES_UHNV  PA2_ANO_UHNV
# 0       NaN       NaN       NaN      NaN           NaN           NaN
# 1       NaN       NaN       NaN      1.0           3.0        1994.0
# 2       NaN       NaN       NaN      1.0          10.0        2013.0
# 3       NaN       NaN       NaN      NaN           NaN           NaN
# 4       NaN       NaN       NaN      NaN           NaN           NaN
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#        TIPO_REG  U_DPTO  U_MPIO  UA_CLASE  COD_ENCUESTAS  U_VIVIENDA  \
# 96792         5       5       1         1         901600           1
# 96793         5       5       1         1         901600           1
# 96794         5       5       1         1         901600           1
# 96795         5       5       1         1         901601           4
# 96796         5       5       1         1         901601           4
#
#        P_NROHOG  P_NRO_PER  P_SEXO  P_EDADR  ...  PA1_THSV  PA2_HSVH  \
# 96792         1          3       2        6  ...      99.0      99.0
# 96793         1          4       1        6  ...       NaN       NaN
# 96794         1          5       1       12  ...       NaN       NaN
# 96795         1          1       2        8  ...       1.0       0.0
# 96796         1          2       2        4  ...       NaN       NaN
#
#        PA3_HSVM  PA_HFC  PA1_THFC  PA2_HFCH  PA3_HFCM  PA_UHNV  PA1_MES_UHNV  \
# 96792      99.0     2.0       NaN       NaN       NaN      1.0           7.0
# 96793       NaN     NaN       NaN       NaN       NaN      NaN           NaN
# 96794       NaN     NaN       NaN       NaN       NaN      NaN           NaN
# 96795       1.0     2.0       NaN       NaN       NaN      1.0           5.0
# 96796       NaN     NaN       NaN       NaN       NaN      NaN           NaN
#
#        PA2_ANO_UHNV
# 96792        2014.0
# 96793           NaN
# 96794           NaN
# 96795        2001.0
# 96796           NaN
#
# [5 rows x 48 columns]

# %%
df.describe()
# Out:
#        TIPO_REG   U_DPTO   U_MPIO  UA_CLASE  COD_ENCUESTAS    U_VIVIENDA  \
# count   96797.0  96797.0  96797.0   96797.0   96797.000000  96797.000000
# mean        5.0      5.0      1.0       1.0  467555.979576     20.940432
# std         0.0      0.0      0.0       0.0  247592.254885     65.376769
# min         5.0      5.0      1.0       1.0    3626.000000      1.000000
# 25%         5.0      5.0      1.0       1.0  256645.000000      2.000000
# 50%         5.0      5.0      1.0       1.0  465583.000000      4.000000
# 75%         5.0      5.0      1.0       1.0  650299.000000     10.000000
# max         5.0      5.0      1.0       1.0  901601.000000    688.000000
#
#            P_NROHOG     P_NRO_PER        P_SEXO       P_EDADR  ...  \
# count  96797.000000  96797.000000  96797.000000  96797.000000  ...
# mean       1.031334      2.578251      1.530895      7.648997  ...
# std        0.305466      1.677919      0.499047      4.243374  ...
# min        1.000000      1.000000      1.000000      1.000000  ...
# 25%        1.000000      1.000000      1.000000      4.000000  ...
# 50%        1.000000      2.000000      2.000000      7.000000  ...
# 75%        1.000000      3.000000      2.000000     11.000000  ...
# max       18.000000     28.000000      2.000000     21.000000  ...
#
#            PA1_THSV      PA2_HSVH      PA3_HSVM        PA_HFC      PA1_THFC  \
# count  28389.000000  28389.000000  28389.000000  28824.000000  11295.000000
# mean       3.772553      2.508366      2.544507      1.611053      0.364320
# std       11.186530     11.146888     11.209523      0.510872      2.241167
# min        0.000000      0.000000      0.000000      1.000000      0.000000
# 25%        1.000000      0.000000      0.000000      1.000000      0.000000
# 50%        2.000000      1.000000      1.000000      2.000000      0.000000
# 75%        3.000000      2.000000      2.000000      2.000000      0.000000
# max       99.000000     99.000000     99.000000      9.000000     99.000000
#
#            PA2_HFCH      PA3_HFCM       PA_UHNV  PA1_MES_UHNV  PA2_ANO_UHNV
# count  11295.000000  11295.000000  28824.000000  21864.000000  21864.000000
# mean       0.194245      0.222399      2.931724      6.548024   2022.360821
# std        2.139045      2.336742      3.423834      3.779941    432.420777
# min        0.000000      0.000000      1.000000      1.000000   1938.000000
# 25%        0.000000      0.000000      1.000000      4.000000   1990.000000
# 50%        0.000000      0.000000      1.000000      7.000000   2001.000000
# 75%        0.000000      0.000000      1.000000     10.000000   2010.000000
# max       99.000000     99.000000      9.000000     99.000000   9999.000000
#
# [8 rows x 48 columns]
